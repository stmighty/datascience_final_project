# %% [markdown]
# # mahidol 2024

# %%
import pandas as pd
df = pd.read_csv('../../data/modified_data_mahidol2024.csv')
df
# Out:
#                                                 article
# 0     Correction to: Effects of customized insoles w...
# 1     Albumin levels in malaria patients: a systemat...
# 2     Enhancing effect of natural adjuvant, pandurat...
# 3     Sesamolin serves as an MYH14 inhibitor to sens...
# 4     Author Correction: Residual renal volume as a ...
# ...                                                 ...
# 1994  Exploring the possibility of carbon neutral di...
# 1995  The Effects of a School-Based Mental Health Pr...
# 1996  Television Viewing and Divorce in Indonesia: E...
# 1997  Networked Governance in Transnational Cooperat...
# 1998  Pension Plan and Household Food Insecurity of ...
#
# [1999 rows x 1 columns]

# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt



text = " ".join(review for review in df.article)
wordcloud = WordCloud(background_color='white').generate(text)
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# # chula

# %%
import pandas as pd
df = pd.read_csv('../../data/output_data_chula.csv')
df
# Out:
#        article_id                                              Title  \
# 0               1  Microencapsulated basil oil (Ocimum basilicum ...
# 1               2  Perceptions Regarding the SARS-CoV-2 Pandemic'...
# 2               3  Construction of a short version of the Montrea...
# 3               4  The effect of strain and pressure on the elect...
# 4               5  Dynamic Cardiopulmonary and Metabolic Function...
# ...           ...                                                ...
# 20211       20212  Estimating actual evapotranspiration from NDVI...
# 20212       20213  Genome-wide association study identified new s...
# 20213       20214  Effects of transcranial direct current stimula...
# 20214       20215  Prevalence and risk factors for canine cogniti...
# 20215       20216  Locus of Control and its Intergenerational Imp...
#
#                                                 Abstract Publication Date  \
# 0      Copyright © 2022 by Animal BioscienceObjective...       2022-05-01
# 1      © 2022 Lippincott Williams and Wilkins. All ri...       2022-04-01
# 2      © 2022 The Author(s). Published by Informa UK ...              NaN
# 3      © 2022 Author(s).Different theoretical methodo...       2022-02-14
# 4      © 2022, Journal of Exercise Physiology Online....              NaN
# ...                                                  ...              ...
# 20211  © 2018 The authors and IOS Press. All rights r...              NaN
# 20212  © 2018 The Author(s).We have performed a genom...       2018-12-01
# 20213  © 2018, Medical Association of Thailand. All r...       2018-01-01
# 20214  © 2018 Chulalongkorn University Printing House...       2018-09-01
# 20215  © 2016 Royal Economic SocietyThis article buil...       2018-02-01
#
#                                             Affiliations  \
# 0      {'Thailand': ['Chulalongkorn University', 'Res...
# 1      {None: ['Neurological Surgery'], 'United State...
# 2      {'Thailand': ['Chulalongkorn University'], 'Bu...
# 3      {'Sweden': ['Linköping University'], 'Thailand...
# 4      {'Thailand': ['Chulalongkorn University', 'Mah...
# ...                                                  ...
# 20211  {'Thailand': ['Khon Kaen University', 'Chulalo...
# 20212  {'Japan': ['University of Tokyo', 'National Ce...
# 20213  {'Thailand': ['Veteran General Hospital', 'Chu...
# 20214  {'Thailand': ['Chulalongkorn University'], 'Un...
# 20215  {'Thailand': ['Chulalongkorn University'], 'Un...
#
#                                                 Keywords  years
# 0      ['Antioxidant Capacity', 'Basil Oil', 'Broiler...   2022
# 1      ['care delivery', 'COVID-19', 'neurocritical c...   2022
# 2      ['Alzheimer’s disease', 'cognitive disorders',...   2022
# 3                                                     []   2022
# 4      ['Bra', 'Cardiorespiratory function', 'Metabol...   2022
# ...                                                  ...    ...
# 20211  ['Actual evapotranspiration', 'Landsat 8', 'ND...   2018
# 20212                                                 []   2018
# 20213  ['Motor cortex', 'Rehabilitation', 'Stroke', '...   2018
# 20214  ['Canine cognitive dysfunction syndrome', 'Pre...   2018
# 20215                                                 []   2018
#
# [20216 rows x 7 columns]

# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = ' '.join(title for title in df['Title'].dropna())  
wordcloud = WordCloud(width = 800, height = 400, background_color ='white').generate(text)

# Display the generated image:
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = ' '.join(title for title in df['Keywords'].dropna())  
wordcloud = WordCloud(width = 800, height = 400, background_color ='white').generate(text)

# Display the generated image:
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
