# %%
import pandas as pd
import numpy as np
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from gensim import corpora, models
import matplotlib.pyplot as plt
import nltk
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis
nltk.download('stopwords')

df = pd.read_csv('../../data/output_data_chula.csv')

def preprocess_text(text):
    tokenizer = RegexpTokenizer(r'\w+')
    stop_words = set(stopwords.words('english'))
    tokens = tokenizer.tokenize(text.lower())
    filtered_words = [w for w in tokens if not w in stop_words and len(w) > 3]
    return filtered_words

df = df.dropna(subset=['Title'])  
df['clean_abstracts'] = df['Title'].apply(preprocess_text)

df = df[df['clean_abstracts'].map(len) > 0]  

dictionary = corpora.Dictionary(df['clean_abstracts'])
corpus = [dictionary.doc2bow(text) for text in df['clean_abstracts']]

# Applying LDA
lda_model = models.ldamodel.LdaModel(corpus, num_topics=5, id2word=dictionary, passes=15)

# Displaying the topics
topics = lda_model.print_topics(num_words=5)
for topic in topics:
    print(topic)

# Visualizing topics
try:
    pyLDAvis.enable_notebook()
    
    lda_visualization = gensimvis.prepare(lda_model, corpus, dictionary, sort_topics=False)
    pyLDAvis.display(lda_visualization)
except ImportError:
    print("some error occurs")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/sirasittanrattanawong/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# (0, '0.016*"patients" + 0.013*"study" + 0.012*"thai" + 0.010*"thailand" + 0.008*"among"')
# (1, '0.017*"proton" + 0.016*"production" + 0.012*"collisions" + 0.009*"search" + 0.007*"analysis"')
# (2, '0.031*"thailand" + 0.010*"thai" + 0.008*"case" + 0.008*"study" + 0.005*"management"')
# (3, '0.026*"using" + 0.021*"based" + 0.009*"detection" + 0.006*"model" + 0.006*"system"')
# (4, '0.010*"activity" + 0.010*"effect" + 0.009*"properties" + 0.009*"acid" + 0.008*"cells"')

# %%
pyLDAvis.display(lda_visualization)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el416841403946803858248946120728" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el416841403946803858248946120728_data = {"mdsDat": {"x": [0.23356417635078222, -0.1643116322773414, 0.16678515550928075, -0.05158286456679093, -0.18445483501593055], "y": [0.15571869025036272, 0.16762592683619773, -0.10360287411061493, -0.24143860702031306, 0.021696864044367384], "topics": [1, 2, 3, 4, 5], "cluster": [1, 1, 1, 1, 1], "Freq": [24.977371768699953, 18.015210526505143, 16.479452615480636, 21.377132045215877, 19.15083304409839]}, "tinfo": {"Term": ["thailand", "using", "patients", "proton", "production", "based", "thai", "collisions", "activity", "detection", "search", "properties", "disease", "study", "among", "cells", "acid", "randomized", "case", "trial", "cell", "clinical", "virus", "nanoparticles", "risk", "systematic", "factors", "outcomes", "controlled", "cancer", "patients", "disease", "randomized", "trial", "clinical", "virus", "outcomes", "controlled", "infection", "therapy", "acute", "children", "prevalence", "chronic", "versus", "liver", "oral", "bone", "syndrome", "kidney", "population", "care", "safety", "early", "hepatitis", "term", "adults", "diabetes", "sectional", "severe", "risk", "efficacy", "among", "meta", "associated", "thai", "study", "factors", "treatment", "related", "thailand", "analysis", "health", "review", "cancer", "quality", "proton", "collisions", "search", "systematic", "boson", "final", "decaying", "quark", "events", "states", "higgs", "fuel", "stem", "pair", "lepton", "canine", "ethanol", "13tev", "cervical", "magnetic", "momentum", "alternative", "major", "biomass", "shrimp", "treated", "differentiation", "transverse", "black", "acids", "production", "measurement", "catalyst", "catalysts", "mass", "cell", "state", "expression", "analysis", "single", "review", "high", "membrane", "cells", "using", "derived", "human", "social", "students", "knowledge", "tropical", "enhance", "chain", "public", "school", "education", "technology", "supply", "urban", "microbial", "regulation", "market", "climate", "attitude", "reproductive", "financial", "policy", "asean", "service", "user", "behaviour", "perspective", "intention", "competitive", "digital", "online", "corporate", "satisfaction", "evidence", "eastern", "thailand", "media", "case", "community", "management", "impact", "thai", "bangkok", "global", "study", "role", "effects", "development", "model", "system", "performance", "factors", "quality", "assessment", "health", "based", "using", "analysis", "detection", "design", "flow", "sensor", "technique", "deep", "composites", "liquid", "paper", "solution", "classification", "fiber", "adsorption", "dimensional", "machine", "polymer", "determination", "dioxide", "problem", "device", "multiple", "finite", "techniques", "neural", "reinforced", "simple", "networks", "sensing", "concrete", "adaptive", "using", "based", "electrochemical", "method", "carbon", "time", "hybrid", "multi", "approach", "process", "data", "system", "model", "water", "learning", "network", "application", "development", "analysis", "study", "performance", "evaluation", "thailand", "phase", "activity", "nanoparticles", "rice", "activities", "antioxidant", "films", "silica", "light", "preparation", "extract", "activation", "reaction", "tio2", "genus", "lactic", "compounds", "facile", "apoptosis", "steam", "plasmodium", "degradation", "coconut", "coated", "observation", "antibacterial", "photocatalytic", "evolution", "theory", "derivatives", "inhibitory", "anti", "properties", "poly", "acid", "cells", "oxide", "effect", "species", "induced", "temperature", "pathway", "synthesis", "cancer", "cell", "natural", "effects", "different", "structure", "enhanced", "rubber", "drug", "high", "characterization", "molecular", "human"], "Freq": [1923.0, 1472.0, 883.0, 675.0, 700.0, 1247.0, 995.0, 468.0, 438.0, 433.0, 352.0, 437.0, 393.0, 1320.0, 528.0, 462.0, 469.0, 323.0, 437.0, 298.0, 546.0, 290.0, 288.0, 231.0, 363.0, 211.0, 409.0, 251.0, 250.0, 391.0, 883.0635599448648, 393.2203200204358, 323.07434721838166, 297.5284856519 ...
